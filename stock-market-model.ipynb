# %%
import yfinance as yf

# %%
import matplotlib as mplot
import matplotlib.pyplot as plt

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-01-11 00:00:00-05:00  4792.129883  4798.500000  4739.580078  4780.240234
# 2024-01-12 00:00:00-05:00  4791.180176  4802.399902  4768.979980  4783.830078
# 2024-01-16 00:00:00-05:00  4772.350098  4782.339844  4747.120117  4765.979980
# 2024-01-17 00:00:00-05:00  4739.129883  4744.229980  4714.819824  4739.209961
# 2024-01-18 00:00:00-05:00  4760.100098  4785.790039  4740.569824  4780.939941
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2024-01-04 00:00:00-05:00', '2024-01-05 00:00:00-05:00',
#                '2024-01-08 00:00:00-05:00', '2024-01-09 00:00:00-05:00',
#                '2024-01-10 00:00:00-05:00', '2024-01-11 00:00:00-05:00',
#                '2024-01-12 00:00:00-05:00', '2024-01-16 00:00:00-05:00',
#                '2024-01-17 00:00:00-05:00', '2024-01-18 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24127, freq=None)

# %%
sp500.plot.line(y="Close", use_index = True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-01-11 00:00:00-05:00  4792.129883  4798.500000  4739.580078  4780.240234
# 2024-01-12 00:00:00-05:00  4791.180176  4802.399902  4768.979980  4783.830078
# 2024-01-16 00:00:00-05:00  4772.350098  4782.339844  4747.120117  4765.979980
# 2024-01-17 00:00:00-05:00  4739.129883  4744.229980  4714.819824  4739.209961
# 2024-01-18 00:00:00-05:00  4760.100098  4785.790039  4740.569824  4780.939941
#
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-01-11 00:00:00-05:00  4792.129883  4798.500000  4739.580078  4780.240234
# 2024-01-12 00:00:00-05:00  4791.180176  4802.399902  4768.979980  4783.830078
# 2024-01-16 00:00:00-05:00  4772.350098  4782.339844  4747.120117  4765.979980
# 2024-01-17 00:00:00-05:00  4739.129883  4744.229980  4714.819824  4739.209961
# 2024-01-18 00:00:00-05:00  4760.100098  4785.790039  4740.569824  4780.939941
#
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-01-11 00:00:00-05:00  4792.129883  4798.500000  4739.580078  4780.240234
# 2024-01-12 00:00:00-05:00  4791.180176  4802.399902  4768.979980  4783.830078
# 2024-01-16 00:00:00-05:00  4772.350098  4782.339844  4747.120117  4765.979980
# 2024-01-17 00:00:00-05:00  4739.129883  4744.229980  4714.819824  4739.209961
# 2024-01-18 00:00:00-05:00  4760.100098  4785.790039  4740.569824  4780.939941
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 900, min_samples_split = 100, random_state=1)

train = sp500.iloc[:-100]

test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]

model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, n_estimators=900, random_state=1)

# %% [markdown]
# ^Bigger n estimators, the higher the accuracy (up to a limit). Min sample split is used to protect against overfitting, the Bigger the min sample split the lower the accuracy but it protects from overfitting. Random state means that when ran twice, the random numbers generated will be a predictable sequence(Its like a seed)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd

preds = pd.Series(preds, index = test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.5333333333333333

# %%
combined = pd.concat([test["Target"],preds], axis = 1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index = test.index, name="Predictions")
    combined = pd.concat([test["Target"],preds], axis = 1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    3452
# 1    2625
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5302857142857142

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.53431
# 0    0.46569
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()

    ratio_column = f"Close_Ratio{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{horizon}"

    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

    new_predictors += [ratio_column, trend_column]

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2024-01-10 00:00:00-05:00  4759.939941  4790.799805  4756.200195  4783.450195
# 2024-01-11 00:00:00-05:00  4792.129883  4798.500000  4739.580078  4780.240234
# 2024-01-12 00:00:00-05:00  4791.180176  4802.399902  4768.979980  4783.830078
# 2024-01-16 00:00:00-05:00  4772.350098  4782.339844  4747.120117  4765.979980
# 2024-01-17 00:00:00-05:00  4739.129883  4744.229980  4714.819824  4739.209961
#
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors]) [:,1]
    preds[preds >= .6] = 1
    preds[preds < .6] = 0
    preds = pd.Series(preds, index = test.index, name="Predictions")
    combined = pd.concat([test["Target"],preds], axis = 1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    4244
# 1.0     832
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5733173076923077

# %%
combined = pd.concat([predictions["Target"],predictions["Predictions"]], axis = 1)

# %%
# Filter data for the specified date range (2020-01-01 to 2024-01-01)
date_range_start = '2022-12-01'
date_range_end = '2023-01-01'

filtered_predictions = predictions[date_range_start:date_range_end]

# Function to plot lines indicating predicted and actual directions with thinner lines
def plot_directions(predictions, title="S&P 500 Stock Price Prediction"):
    plt.figure(figsize=(14, 7))
    
    # Plot lines indicating predicted direction
    plt.plot(predictions.index, predictions['Predictions'], label='Predicted', color='orange', linestyle='-', marker='o', linewidth=1)
    
    # Plot lines indicating actual direction
    plt.plot(predictions.index, predictions['Target'], label='Actual', color='blue', linestyle='-', marker='x', linewidth=1)
    
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Direction (0: Down, 1: Up)')
    plt.legend()
    plt.show()

# Plot backtested predictions and actual directions with thinner lines for the specified date range
plot_directions(filtered_predictions)
